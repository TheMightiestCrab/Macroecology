# %% [markdown]
# Import libraries and set path for cleaned CSV file.

# %%
import pandas as pd
import numpy as np

OUTPUT_PATH = "../data/cleaned scavenger data.csv"

# %% [markdown]
# Read the data, excluding the columns Cara and I used for bookkeeping. I will index by species names rather than by row numbers to make working with the DataFrame more intuitive.

# %%
columns = [
    "Species name",
    "Scientific name",
    "Diet",
    "Extent of occurrence",
    "BirdLife Extent of occurrence",
    "Body size",
]

scavengers = pd.read_csv(
    "../data/MacroEco scavenger data.csv", usecols=columns, index_col="Species name"
)
scavengers.head()
# Out:
#                                      Scientific name      Diet  \
# Species name
# Black vulture                       Coragyps atratus  Obligate
# Turkey vulture                        Cathartes aura  Obligate
# Lesser yellow headed vulture   Cathartes burrovianus  Obligate
# Greater yellow headed vulture  Cathartes melambrotus  Obligate
# King vulture                       Sarcoramphus papa  Obligate
#
#                                Extent of occurrence  \
# Species name
# Black vulture                            42593865.0
# Turkey vulture                           52285085.0
# Lesser yellow headed vulture             19989926.0
# Greater yellow headed vulture             7481821.0
# King vulture                             17390218.0
#
#                                BirdLife Extent of occurrence  Body size
# Species name
# Black vulture                                     44300000.0       2200
# Turkey vulture                                    47100000.0       2500
# Lesser yellow headed vulture                      19600000.0        950
# Greater yellow headed vulture                      7330000.0       1650
# King vulture                                      22600000.0       3800

# %% [markdown]
# Find and display any rows that have `NaN` (Not a Number) values.

# %%
scavengers.loc[scavengers.isnull().any(axis=1)]
# Out:
#              Scientific name         Diet  Extent of occurrence  \
# Species name
# Hooded crow    Corvus cornix  Facultative           21136393.72
#
#               BirdLife Extent of occurrence  Body size
# Species name
# Hooded crow                             NaN        650

# %% [markdown]
# BirdLife currently lists no data for the extent of occurrence (EOO) for the hooded crow, so let's drop it from our dataset.

# %%
scavengers.drop(["Hooded crow"], inplace=True)

# %% [markdown]
# Let's add new columns that have the log-transformed values for EOO and body size. We will use the base 10 system, because we are dealing with spatial ranges and it is easier to interpret distances in $log_{10}$ than the natural log, which uses base $e$.

# %%
scavengers["log Extent of occurrence"] = np.log10(scavengers["Extent of occurrence"])
scavengers["log Body size"] = np.log10(scavengers["Body size"])

scavengers.head()
# Out:
#                                      Scientific name      Diet  \
# Species name
# Black vulture                       Coragyps atratus  Obligate
# Turkey vulture                        Cathartes aura  Obligate
# Lesser yellow headed vulture   Cathartes burrovianus  Obligate
# Greater yellow headed vulture  Cathartes melambrotus  Obligate
# King vulture                       Sarcoramphus papa  Obligate
#
#                                Extent of occurrence  \
# Species name
# Black vulture                            42593865.0
# Turkey vulture                           52285085.0
# Lesser yellow headed vulture             19989926.0
# Greater yellow headed vulture             7481821.0
# King vulture                             17390218.0
#
#                                BirdLife Extent of occurrence  Body size  \
# Species name
# Black vulture                                     44300000.0       2200
# Turkey vulture                                    47100000.0       2500
# Lesser yellow headed vulture                      19600000.0        950
# Greater yellow headed vulture                      7330000.0       1650
# King vulture                                      22600000.0       3800
#
#                                log Extent of occurrence  log Body size
# Species name
# Black vulture                                  7.629347       3.342423
# Turkey vulture                                 7.718378       3.397940
# Lesser yellow headed vulture                   7.300811       2.977724
# Greater yellow headed vulture                  6.874007       3.217484
# King vulture                                   7.240305       3.579784

# %% [markdown]
# Export to CSV.

# %%
scavengers.to_csv(OUTPUT_PATH)
